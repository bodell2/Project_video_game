# %% [markdown]
# <a href="https://colab.research.google.com/github/bodell2/Project_video_game/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time 
def check_time(s_time, pname, current_room):
  if time.time()-s_time > 600:
    death_note = p_name + " couldn't make it out of " + current_room
    return death_note
  else:
    return ''

def to_third_person(str1, name):
  str1 = str1.lower()
  return str1.replace('i ', name + ' ') + ' \n'

def check_action(act, dict):
  if act.lower() in dict.keys():
    dict[act.lower()] -= 1
    if dict[act.lower()] == 0:
      del dict[act.lower()]
    else:
      pass
    return dict
  else:
    return None
time_start= time.time()

# %%
#Escape the Mansion
#Room_1()


Actions = {'run':2, 'crawl':2, 'smash':1}
p_name=str(input("Enter player name: "))
time_start = time.time()

valid = False
while time.time()-time_start < 600 and not valid:
  p_name = p_name.strip()
  print('')
  str1 = 'Welcome, '
  file1 = open("story_txt.txt", 'w')
  file1.write(str1 + p_name +'\n')
  file1.close()

  ## Room_1
  file2 = open('StoryLine.txt, 'r')
  print(file2.read(263))
  file2.close()
  print('')

  print("Actions:", end='')
  print(Actions)
  valid_input = False
  while not valid_input:
    action1 = str(input("Choose an action: "))
    check_action(action1, Actions)
    if action1.lower() == 'run' or action1.lower() == 'crawl':
      valid_input = True
    else:
      print('Try again!')
        
  print('')


  Room1_Tools = ('key')
  print("Tools: ", end='')
  print(Room1_Tools)
  valid_input = False
  while not valid_input:
    Tool = str(input("Choose the tool you will use: "))
    if Tool.lower() == Room1_Tools[0:]:
      valid_input = True
    else:
      print('IDK about that one. Try again.') 

  print('')

  ## Get the user to write a string telling what happens so that we can add that 
  ## to a separate file

  User_Input = str(input('Explain how you escaped using the tool and action you chose: '))

  file1 = open("story_txt.txt", 'a')
  file1.write('In Room 1, '+to_third_person(User_Input, p_name))
  file1.close()
  valid = True

file1 = open("story_txt.txt", 'a')
file1.write(check_time(time_start, p_name, 'Room 1'))
file1.close()
# Out:
#   File "<ipython-input-97-64a04f872213>", line 19
#     file2 = open('StoryLine.py, 'r')
#                                     ^
# SyntaxError: EOL while scanning string literal

# %%
## Room 2
#Room_2
valid = False
while time.time()-time_start < 600 and not valid:
  file2 = open('StoryLine.txt', 'r')
  print(file2.read(623)[263:])
  file2.close()
  print('')

  print("Actions:", end='')
  print(Actions)
  valid_input = False
  while not valid_input:
    action2 = str(input("Choose an action: "))
    check_action(action2, Actions)
    if action2.lower() == 'smash':
      valid_input = True
    else:
      print('Try again!')


  print('')


  Room2_Tools = ('broomstick', 'axe')
  print("Tools: ", end='')
  print(Room2_Tools)
  valid_input = False
  while not valid_input:
    Tool = str(input("Choose the tool you will use: "))
    if Tool.lower() == Room2_Tools[1]:
      valid_input = True
    else:
      print('IDK about that one. Try again.') 

  print('')

  ## Get the user to write a string telling what happens so that we can add that 
  ## to a separate file

  User_Input = str(input('Explain how you escaped using the tool and action you chose: '))

  file1 = open("story_txt.txt", 'a')
  file1.write('In Room 2, '+to_third_person(User_Input, p_name))
  file1.close()
  valid = True

file1 = open("story_txt.txt", 'a')
file1.write(check_time(time_start, p_name, 'Room 2'))
file1.close()
# Out:
# Room 2
#
# Now you are in the cellar and the smell is just as awful as before. You need to hurry because
# you haven't had any water and you are starting to feel the effects of dehydration. Luckily,
# you can see as there is a bit of light light pouring through a small window near the ceiling. You cannot fit
# through it and the door is the only way out. Escape!
#
# Actions:{'run': 2, 'crawl': 2}
# Choose an action: run
# Try again!
# Choose an action: crawl
# Try again!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-fe55f473ffd5> in <module>()
#      12   valid_input = False
#      13   while not valid_input:
# ---> 14     action2 = str(input("Choose an action: "))
#      15     check_action(action2, Actions)
#      16     if action2.lower() == 'smash':
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
## Room 3
# Room_3
Actions = {'run':2, 'crawl':2}
valid = False

time_start=time.time()

while time.time()-time_start < 600 and not valid:
  file2 = open('StoryLine.txt', 'r')
  print(file2.read(1078)[624:])
  file2.close()
  print('')

  print("Actions:", end='')
  print(Actions)
  valid_input = False
  while not valid_input:
    action2 = str(input("Choose an action: "))
    check_action(action2, Actions)
    if action2.lower() == 'run':
      valid_input = True
    else:
      print('Maybe we shouldn\'t do that right now!')


  print('')


  Room3_Tools = ('knife', 'pan', 'water')
  print("Tools: ", end='')
  print(Room3_Tools)
  valid_input = False
  while not valid_input:
    Tool = str(input("Choose the tool you will use: "))
    if Tool.lower() == Room3_Tools[1]:
      valid_input = True
      print('After running around the room, you found a pan! Maybe you can slash something down?')
    elif Tool.lower() == Room3_Tools[0]:
      valid_input = True
      print('After running around the room you found a knife! Maybe you can smash something down?')
    else:
      print('Maybe try something sturdier.') 

  print('')

  ## Get the user to write a string telling what happens so that we can add that 
  ## to a separate file

  User_Input = str(input('Explain how you escaped using the tool and action you chose: '))

  file1 = open("story_txt.txt", 'a')
  file1.write('In Room 3, '+to_third_person(User_Input, p_name))
  file1.close()
  valid = True

file1 = open("story_txt.txt", 'a')
file1.write(check_time(time_start, p_name, 'Room 3'))
file1.close()
# Out:
# Room 3
#
# You have made it to the kitchen and thankfully you were able to find some water before it was
# too late. Your timer has been reset, but this should not diminish your sense of urgency! The
# food is all rotten and the smell is horrific, you need to get out of there before you once . There are windows that reveal that it is now night time. Unfortunately
# they are unbreakable so you will have to find another way out. Escape through the air vents!
#
#
# Actions:{'run': 2, 'crawl': 2}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-f8d73806f757> in <module>()
#      16   valid_input = False
#      17   while not valid_input:
# ---> 18     action2 = str(input("Choose an action: "))
#      19     check_action(action2, Actions)
#      20     if action2.lower() == 'run':
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
## Room 4
# Room_4
Actions = {'run':2, 'crawl':2}
valid = False
while time.time()-time_start < 600 and not valid:
  file2 = open('StoryLine.txt', 'r')
  print(file2.read(1309)[1078:])
  file2.close()
  print('')

  print("Actions:", end='')
  print(Actions)
  valid_input = False
  while not valid_input:
    action2 = str(input("Choose an action: "))
    check_action(action2, Actions)
    if action2.lower() == 'run':
      valid_input = True
    else:
      print('Maybe not now!')


  print('')


  Room4_Tools = ('axe',  'paperclip', 'phone charger')
  print("Tools: ", end='')
  print(Room4_Tools)
  valid_input = False
  while not valid_input:
    Tool = str(input("Choose the tool you will use: "))
    if Tool.lower() == Room4_Tools[1]:
      valid_input = True
      print('Maybe you can try picking a lock with it?')
    elif Tool.lower() == Room4_Tools[0]:
      valid_input = True
      print('Maybe you can smash something with it?')
    else:
      print('This? There\'s a time and place for everything! But not now...') 

  print('')

  ## Get the user to write a string telling what happens so that we can add that 
  ## to a separate file

  User_Input = str(input('Explain how you escaped using the tool and action you chose: '))

  file1 = open("story_txt.txt", 'a')
  file1.write('In Room 4, '+to_third_person(User_Input, p_name))
  file1.close()
  valid = True

file1 = open("story_txt.txt", 'a')
file1.write(check_time(time_start, p_name, 'Room 4'))
file1.close()
# Out:
# Room 4
#
# Exiting the kitchen, you find yourself in the living room where there are no windows and the
# only light is coming from the static of an old TV. It looks like the fire place is two-sided.
# Get through the divider to escape.
#
# Actions:{'run': 2, 'crawl': 2}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-472f535cf0b5> in <module>()
#      13   valid_input = False
#      14   while not valid_input:
# ---> 15     action2 = str(input("Choose an action: "))
#      16     check_action(action2, Actions)
#      17     if action2.lower() == 'run':
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
  ## Room 5

# Room_5
valid=False 
while time.time()-time_start < 600 and not valid:
    file2 = open('StoryLine.txt', 'r')
    print(file2.read(1415)[1309:])
    file2.close()
    print('')

    print("Actions:", end='')
    print(Actions)
    valid_input = False
    while not valid_input:
      action1 = str(input("Choose an action: "))
      check_action(action1, Actions)
      if action1.lower() == 'run' or action1.lower() == 'smash':
        valid_input = True
      else:
        print('Maybe not now!')
          
    print('')


    Room5_Tools = ('fist',  'bowling ball', 'ace of spades')
    print("Tools: ", end='')
    print(Room5_Tools)
    valid_input = False
    while not valid_input:
      Tool = str(input("Choose the tool you will use: "))
      if Tool.lower() == Room5_Tools[0]:
        time_start+=20
        valid_input = True
      elif Tool.lower()==Room5_Tools[1]:
        valid_input=True
      else:
        print('I don\'t think that\'s gonna help here') 

        print('')

        ## Get the user to write a string telling what happens so that we can add that 
        ## to a separate file

        User_Input = str(input('Explain how you escaped using the tool and action you chose: '))

        file1 = open("story_txt.txt", 'a')
        file1.write('In Room 5, '+to_third_person(User_Input, p_name))
        file1.close()
        valid = True

  file1 = open("story_txt.txt", 'a')
  file1.write(check_time(time_start, p_name, 'Room 5'))
  file1.close()

# %%
  ## Roof


valid=False
Actions_roof={'slide':1, 'walk':1, 'run':1}
while time.time()-time_start < 600 and not valid:
    file2 = open('StoryLine.txt', 'r')
    print(file2.read(1499)[1415:])
    file2.close()
    print('')

    print("Actions:", end='')
    print(Actions_roof)
    valid_input = False
    while not valid_input:
      action1 = str(input("Choose an action: "))
      check_action(action1, Actions_roof)
      if action1.lower() == 'slide' or action1.lower() == 'walk':
        valid_input = True
      else:
        print('Probably not the best option.')
          
    print('')


    Room6_Tools = ('rope',  'roof tile', 'bird\'s nest')
    print("Tools: ", end='')
    print(Room6_Tools)
    valid_input = False
    while not valid_input:
        Tool = str(input("Choose the tool you will use: "))
        if Tool.lower() == Room6_Tools[0]:
          valid_input = True
        else:
          print('What was the plan with this?') 

        print('')

        ## Get the user to write a string telling what happens so that we can add that 
        ## to a separate file

        User_Input = str(input('Explain how you escaped using the tool and action you chose: '))

        file1 = open("story_txt.txt", 'a')
        file1.write('On the roof, '+to_third_person(User_Input, p_name))
        file1.close()
        valid = True  

file1 = open("story_txt.txt", 'a')
file1.write(check_time(time_start, p_name, 'Room 6'))
file1.close()
# Out:
# Roof
#
# This roof is kind of high. How should you get down? Beware, time is ticking!
#
# Actions:{'slide': 1, 'walk': 1, 'run': 1}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-3baa496c21f0> in <module>()
#      14   valid_input = False
#      15   while not valid_input:
# ---> 16     action1 = str(input("Choose an action: "))
#      17     check_action(action1, Actions_roof)
#      18     if action1.lower() == 'slide' or action1.lower() == 'walk':
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
  #Ending Scene

print('You Escaped!')
print('')
print('Here\'s a recap of your adventure')

file1 = open('story_txt.txt', 'r')
print(file1.read())
file1.close()
print('')
# Out:
# You Escaped!
#
# Here's a recap of your adventure
# Welcome, Ethan
# In Room 1, Ethan ran to the door and unlocked with a key.
# In Room 2, Ethan smashed the door with an axe
